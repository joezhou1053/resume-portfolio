# %% [markdown]
# # LSTM definition
# Long Short-Term Memory(LSTM)is a type of Recurrent Neural Network(RNN)that can capture long-term dependencies in sequential data.

# %% [markdown]
# - They use a memory cell and gates to control the flow of information,allowing them to selectively retain or discard information as needed and thus avoid the vanishing gradient problem that plagues(烦扰，纠缠) traditional RNNS.
# - LSTMs are engineered to address the vanishing gradient problem that occurs in traditional RNNs, enabling better learning of long-term dependencies.
# - LSTMs retain information using a memory cell regulated by input, forget, and output gates that control how data flows through the network.

# %% [markdown]
# # RNN Definition
# can do LSTM by using a hidden state passed from one timestamp to the next.

# %% [markdown]
# - RNN can capture short-term dependencies in sequential data, but they struggle with capturing long-term dependencies.
# - RNNs capture sequential dependencies by continuously updating a hidden state that integrates current inputs with previous context.
# - RNNs forecast future sequence steps by utilizing information from previous outputs and hidden states to maintain context over time.
